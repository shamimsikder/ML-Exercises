# %%
# Import pandas
import pandas as pd

# %%
# Create a series of three different colours
Colour = pd.Series(["Black","Blue","Red"])

# %%
# Print Colours Series
Colour
# Out:
# 0    Black
# 1     Blue
# 2      Red
# dtype: object

# %%
# Create a series of three different car companny
Cars = pd.Series(["BMW","Audi","Ford"])

# %%
#Print Cars Series
Cars
# Out:
# 0     BMW
# 1    Audi
# 2    Ford
# dtype: object

# %%
# Combine Cars and Colours Series
s = pd.DataFrame({"Cars":Cars,"Colour":Colour})

# %%
# Print s
s
# Out:
#    Cars Colour
# 0   BMW  Black
# 1  Audi   Blue
# 2  Ford    Red

# %%
# Export the DataFrame to A CSV File
s.to_csv("Practice_Data.csv")

# %%
# Find the datatypes of s
s.dtypes
# Out:
# Cars      object
# Colour    object
# dtype: object

# %%
# use describe method for describe s DataFrame
s.describe()
# Out:
#        Cars Colour
# count     3      3
# unique    3      3
# top     BMW  Black
# freq      1      1

# %%
# Get information of s
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Cars    3 non-null      object
#  1   Colour  3 non-null      object
# dtypes: object(2)
# memory usage: 176.0+ bytes

# %%
# Create a Series and find mean
num = pd.Series([10,21,56,43,32])
num.mean()
# Out:
# 32.4

# %%
# Find the sum of that series
num.sum()
# Out:
# 162

# %%
# import car-sales.csv data and find all columns name
df = pd.read_csv("car-sales.csv")
df.columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
# Find 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 528.0+ bytes

# %%
# Show the first 5 rows of the car sales DataFrame
df.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
# Show the first 7 rows of the car sales DataFrame
df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
# Show the bottom 5 rows of the car sales DataFrame
df.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
# Use .loc to select the row at index 3 of the car sales DataFrame
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Use .iloc to select the row at position 3 of the car sales DataFrame
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
# Select the "Odometer (KM)" column from the car sales DataFrame
df["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
# Find the mean of the "Odometer (KM)" column in the car sales DataFrame
df["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
# Select the rows with over 100,000 kilometers on the Odometer
df[df["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
# Create a crosstab of the Make and Doors columns
pd.crosstab(df["Make"],df["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
# Group columns of the car sales DataFrame by the Make column and find the average
df.groupby(["Make"]).mean()
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# Import Matplotlib and create a plot of the Odometer column
# Don't forget to use %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# Create a histogram of the Odometer column using hist()
df.hist();

# %%
# Try to plot the Price column using plot()
df.plot()
# Out:
# <AxesSubplot:>

# %%
# Remove the punctuation from price column
df["Price"] = df["Price"].replace('[\$,\.]',"",regex=True)

# %%
# Check the changes to the price column
df
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
# Remove the two extra zeros at the end of the price column
df["Price"] = df["Price"].str[:-2]

# %%
# Check the changes to the Price column
df
# Out:
#      Make Colour  Odometer (KM)  Doors  Price
# 0  Toyota  White         150043      4   4000
# 1   Honda    Red          87899      4   5000
# 2  Toyota   Blue          32549      3   7000
# 3     BMW  Black          11179      5  22000
# 4  Nissan  White         213095      4   3500
# 5  Toyota  Green          99213      4   4500
# 6   Honda   Blue          45698      4   7500
# 7   Honda   Blue          54738      4   7000
# 8  Toyota  White          60000      4   6250
# 9  Nissan  White          31600      4   9700

# %%
# Change the datatype of the Price column to integers
df["Price"] = df["Price"].astype(int)

# %%
# Lower the strings of the Make column
df["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# Make lowering the case of the Make column permanent
df["Make"] = df["Make"].str.lower()

# %%
# Check the car sales DataFrame
df["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
# Import the car sales DataFrame with missing data ("../data/car-sales-missing-data.csv")

car = pd.read_csv("car-sales-missing-data.csv")
# Check out the new DataFrame
car
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
# Fill the Odometer (KM) column missing values with the mean of the column inplace
car["Odometer"] = car["Odometer"].fillna(car["Odometer"].mean())

# %%
# View the car sales missing DataFrame and verify the changes
car
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
# Remove the rest of the missing data inplace
car.dropna(inplace=True)

# %%
# Verify the missing values are removed by viewing the DataFrame
car
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %% [markdown]
# We'll now start to add columns to our DataFrame.

# %%
# Create a "Seats" column where every row has a value of 5
seats = 5
car["Seats"] = seats
car
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
# Create a column called "Engine Size" with random values between 1.3 and 4.5
# Remember: If you're doing it from a Python list, the list has to be the same length
# as the DataFrame
car["Engine Size"] = pd.DataFrame({"Engine Size":[1.3,1.7,2.5,4.5,3.2,3.8]})
car
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   $4,000      5          1.3
# 1   Honda    Red   87899.000000    4.0   $5,000      5          1.7
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5          2.5
# 3     BMW  Black   11179.000000    5.0  $22,000      5          4.5
# 4  Nissan  White  213095.000000    4.0   $3,500      5          3.2
# 5  Toyota  Green   92302.666667    4.0   $4,500      5          3.8

# %%
# Create a column which represents the price of a car per kilometer
# Then view the DataFrame

car["Price"] = car["Price"].replace('[/$,\.]',"",regex=True).astype(int)

car["Price Per KM"] = car["Price"] / car["Odometer"]

car
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3
# 1   Honda    Red   87899.000000    4.0   5000      5          1.7
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.5
# 3     BMW  Black   11179.000000    5.0  22000      5          4.5
# 4  Nissan  White  213095.000000    4.0   3500      5          3.2
# 5  Toyota  Green   92302.666667    4.0   4500      5          3.8
#
#    Price Per KM
# 0      0.026659
# 1      0.056883
# 2      0.075837
# 3      1.967976
# 4      0.016425
# 5      0.048753

# %%
# Remove the last column you added using .drop()
car.drop("Price Per KM",axis=1)
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3
# 1   Honda    Red   87899.000000    4.0   5000      5          1.7
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.5
# 3     BMW  Black   11179.000000    5.0  22000      5          4.5
# 4  Nissan  White  213095.000000    4.0   3500      5          3.2
# 5  Toyota  Green   92302.666667    4.0   4500      5          3.8

# %%
# Shuffle the DataFrame using sample() with the frac parameter set to 1
# Save the the shuffled DataFrame to a new variable
suffle = car.sample(frac=1)
suffle
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 3     BMW  Black   11179.000000    5.0  22000      5          4.5
# 5  Toyota  Green   92302.666667    4.0   4500      5          3.8
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.5
# 0  Toyota  White  150043.000000    4.0   4000      5          1.3
# 1   Honda    Red   87899.000000    4.0   5000      5          1.7
# 4  Nissan  White  213095.000000    4.0   3500      5          3.2
#
#    Price Per KM
# 3      1.967976
# 5      0.048753
# 2      0.075837
# 0      0.026659
# 1      0.056883
# 4      0.016425

# %%
# Reset the indexes of the shuffled DataFrame
suffle.reset_index(drop=True,inplace=True)
suffle
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 0     BMW  Black   11179.000000    5.0  22000      5          4.5
# 1  Toyota  Green   92302.666667    4.0   4500      5          3.8
# 2  Toyota   Blue   92302.666667    3.0   7000      5          2.5
# 3  Toyota  White  150043.000000    4.0   4000      5          1.3
# 4   Honda    Red   87899.000000    4.0   5000      5          1.7
# 5  Nissan  White  213095.000000    4.0   3500      5          3.2
#
#    Price Per KM
# 0      1.967976
# 1      0.048753
# 2      0.075837
# 3      0.026659
# 4      0.056883
# 5      0.016425

# %%
# Change the Odometer values from kilometers to miles using a Lambda function
# Then view the DataFrame
suffle["Odometer"] = suffle["Odometer"].apply(lambda x:x/1.6)
suffle
# Out:
#      Make Colour       Odometer  Doors  Price  Seats  Engine Size  \
# 0     BMW  Black    6986.875000    5.0  22000      5          4.5
# 1  Toyota  Green   57689.166667    4.0   4500      5          3.8
# 2  Toyota   Blue   57689.166667    3.0   7000      5          2.5
# 3  Toyota  White   93776.875000    4.0   4000      5          1.3
# 4   Honda    Red   54936.875000    4.0   5000      5          1.7
# 5  Nissan  White  133184.375000    4.0   3500      5          3.2
#
#    Price Per KM
# 0      1.967976
# 1      0.048753
# 2      0.075837
# 3      0.026659
# 4      0.056883
# 5      0.016425
